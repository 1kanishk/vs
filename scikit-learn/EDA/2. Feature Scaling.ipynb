# %% [raw]
# Feature scaling is a data preprocessing technique used to bring all numerical features to a similar scale so that no single feature dominates the model due to its larger magnitude.

# %% [raw]
# What is Normalization?
# Normalization is a scaling technique in which values are shifted and rescaled so that they end up ranging between 0 and 1. It is also known as Min-Max scaling.
# Normalization → scales values to a fixed range (usually 0 to 1)

# %% [raw]
# What is Standardization?
# Standardization is another scaling technique where the values are centered around the mean with a unit standard deviation. This means that the mean of the attribute becomes zero and the resultant distribution has a unit standard deviation.
# Standardization → scales values to mean = 0 and standard deviation = 1

# %% [raw]
# Normalization (Min–Max Scaling)
#
# When to use :-
# 1. Data has no outliers or very few
# 2. Features have known, fixed bounds
# 3. You are using distance-based algorithms
# KNN, K-Means, Neural Networks (sometimes)
# 4. You need values strictly between 0 and 1
#
# Why :-
# 1. Preserves relative distances
# 2. Makes features directly comparable
#
# How (sklearn) :-
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# X_scaled = scaler.fit_transform(X)

# %% [raw]
# Standardization (Z-Score Scaling)
#
# When to use :-
# 1. Data contains outliers or extreme values
# 2. Features follow an approximately normal (Gaussian) distribution
# 3. You are using gradient-based or linear models
# Linear Regression, Logistic Regression, SVM, PCA
#
# Why :-
# 1. Centers data at zero
# 2. Scales features to unit standard deviation = 1
# 3. Improves model convergence and stability
#
# Reduces the impact of outliers compared to normalization
#
# How (sklearn) :-
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r'D:\codes\scikit-learn\EDA\feature-scaling-3-1639387457.webp')
plt.imshow(img)
plt.show()
