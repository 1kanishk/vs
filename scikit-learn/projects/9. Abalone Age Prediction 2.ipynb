# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('abalone.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
cat_col = ['Sex']

num_cols = [
    'Length',
    'Diameter',
    'Height',
    'Whole weight',
    'Shucked weight',
    'Viscera weight',
    'Shell weight'
]

# %%
x = df.drop('Rings', axis=1)
y = df['Rings']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
pipe = Pipeline(
    steps=[
        ('ohe',OneHotEncoder())
    ]
)

pipe2 = Pipeline(
    steps=[
        ('sc',StandardScaler())
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('encoding',pipe,cat_col),
        ('scaling',pipe2,num_cols)
    ]
)

# %%
pipe_lr = Pipeline(
    steps=[
        ("prep",preprocessor),
        ("lr",LinearRegression())
    ]
)

pipe_rf = Pipeline(
    steps=[
    ('prep',preprocessor),
    ('clf', RandomForestRegressor())
    ]
)

# %%
pipe_lr.fit(x_train,y_train)
pipe_rf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('encoding',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder())]),
#                                                   ['Sex']),
#                                                  ('scaling',
#                                                   Pipeline(steps=[('sc',
#                                                                    StandardScaler())]),
#                                                   ['Length', 'Diameter',
#                                                    'Height', 'Whole weight',
#                                                    'Shucked weight',
#                                                    'Viscera weight',
#                                                    'Shell weight'])])),
#                 ('clf', RandomForestRegressor())])

# %%
y_pred_lr = pipe_lr.predict(x_test)
y_pred_rf  = pipe_rf.predict(x_test)

# %%
mae_lr = mean_absolute_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred_lr))
r2_lr = r2_score(y_test, y_pred_lr)

print("Linear Regression:")
print("MAE :", mae_lr)
print("RMSE:", rmse_lr)
print("R2  :", r2_lr)
# Out:
# Linear Regression:
# MAE : 1.5931067816608366
# RMSE: 2.2116130871218367
# R2  : 0.5481628137889263

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

print("randomf reg:")
print("MAE :", mae_rf)
print("RMSE:", rmse_rf)
print("R2  :", r2_rf)
# Out:
# randomf reg:
# MAE : 1.5801674641148324
# RMSE: 2.244954310550513
# R2  : 0.5344367605571252
